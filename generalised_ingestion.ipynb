# %%
from datetime import datetime
import pystac
from pystac.extensions.eo import EOExtension
from pystac.extensions.sat import SatExtension
import os
from minio import Minio
import tifffile
from pathlib import Path
import zarr
import numpy as np
import shutil
import re
from dateutil import parser
from PIL import Image
import xmltodict
from dotenv import load_dotenv
import json

# %%
load_dotenv()
# Out:
# True

# %%
# Function to recursively upload to minio server
def upload_to_minio(client, bucket_name, local_path, minio_path):
    """Upload a file or directory to MinIO server"""
    if os.path.isfile(local_path):
        client.fput_object(bucket_name, minio_path, local_path)
    elif os.path.isdir(local_path):
        for root, _, files in os.walk(local_path):
            for file in files:
                local_file_path = os.path.join(root, file)
                minio_file_path = os.path.join(minio_path, os.path.relpath(local_file_path, local_path))
                client.fput_object(bucket_name, minio_file_path, local_file_path)

# %%
# Minio client setup
minio_client = Minio(
    os.getenv("MINIO_ENDPOINT", "localhost:9000"),
    access_key=os.getenv("MINIO_ACCESS_KEY", "minioadmin"),
    secret_key=os.getenv("MINIO_SECRET_KEY", "minioadmin"),
    secure=False 
)

# %%
bucket_name = os.getenv('S3_BUCKET_NAME')
data_dir = Path(os.getenv('DATA_DIR'))

# %%
# Ensure the bucket exists
if not minio_client.bucket_exists(bucket_name):
    print(f"Creating bucket: {bucket_name}")
    minio_client.make_bucket(bucket_name)

# %%
scenes_dir = data_dir / "Scenes"
masks_dir = data_dir / "Masks"
metadata_dir = data_dir / "Metadata"

data = json.load((data_dir / "data.json").open())

# %%
print(data)
# Out:
# {'platform': 'sentinel-2', 'band_layout': 'disjoint', 'bands': {'ultra-blue': 'B01', 'blue': 'B02', 'green': 'B03', 'red': 'B04', 'vnir': 'B08', 'swir': 'B11'}, 'notes': 'Each band is a separate single-band GeoTIFF', 'metadata_available': True, 'cloud_cover_available': True}

# %%
# Tiling function to split images into tiles
def tile_image(image, tile_size=(384, 384)):
    h, w = image.shape[:2]
    tiles = []

    for y in range(0, h, tile_size[0]):
        for x in range(0, w, tile_size[1]):
            tile = image[y:y+tile_size[0], x:x+tile_size[1]]
            tiles.append(tile)

    return tiles 

# Function to pad tiles to deal with edges
def pad_to_shape(tile, shape=(384, 384)):
    padded = np.zeros(shape, dtype=tile.dtype)
    h, w = tile.shape
    padded[:h, :w] = tile
    return padded

# Function to calculate the percentage of white pixels in a mask
def white_percentage_batch(masks):
    masks_flat = masks.reshape(masks.shape[0], -1)
    white = np.sum(masks_flat == 255, axis=1)
    black = np.sum(masks_flat < 255, axis=1)
    total = white + black
    with np.errstate(divide='ignore', invalid='ignore'):
        percentages = np.where(total > 0, (white / total) * 100, 0.0)
    return percentages

# %%
# Function to upload Zarr data to MinIO
def upload_zarr(image,variable_name,bucket_name):
    # Name the tile and create a local Zarr store
    tile_name = f"{variable_name}"
    local_zarr_store_path = f"{tile_name}.zarr"
    local_zarr_store_path_str = str(local_zarr_store_path)
    root_group = zarr.open_group(local_zarr_store_path_str, mode='w')
    
    # Set dimensions and chunks
    if image.ndim == 2:
        dimension_names = ['y', 'x']
        zarr_array_chunks = (384,384)
    elif image.ndim == 3:
        dimension_names = ['y', 'x', 'band']
        zarr_array_chunks = (384,384, 1)
    else:
        raise ValueError(f"Unsupported image shape: {image.shape}")
    
    # Create the Zarr array with the specified dimensions and chunks
    z_array = root_group.create_dataset(
        name=tile_name,
        data=image,
        chunks=zarr_array_chunks,
        dtype=image.dtype,
        overwrite=True
    )
    
    # Set attributes for the Zarr array
    z_array.attrs['_ARRAY_DIMENSIONS'] = dimension_names
    zarr.consolidate_metadata(local_zarr_store_path_str)
    
    # Upload the Zarr store to MinIO and delete the local store
    minio_zarr_path_prefix = f"mask/{tile_name}.zarr"
    upload_to_minio(minio_client, bucket_name, local_zarr_store_path, minio_zarr_path_prefix)
    shutil.rmtree(local_zarr_store_path_str)
    
    print(f"Uploaded tiles for variable '{variable_name}' to MinIO bucket '{bucket_name}'.")

# %%
# To parse metadata files based on platform
def parse_mtl(mtl_path,data):
    if data["platform"] == "landsat-8":
        metadata = {}
        pattern = re.compile(r'(\w+)\s=\s"?(.*?)"?$')
        with open(mtl_path, 'r') as file:
            for line in file:
                match = pattern.search(line.strip())
                if match:
                    key, val = match.groups()
                    metadata[key] = val
    elif data["platform"] == 'sentinel-2':
        metadata = {}
        with open(mtl_path,'r') as f:
            metadata  = xmltodict.parse(f.read())
    return metadata

# %%
def make_stac_item(metadata, zarr_path, tile_id, cloud_cover, data):
    
    if data["platform"] == "landsat-8" and data["metadata_available"]:
        # Bounding box (UL, LR)
        ul_lat = float(metadata["CORNER_UL_LAT_PRODUCT"])
        ul_lon = float(metadata["CORNER_UL_LON_PRODUCT"])
        lr_lat = float(metadata["CORNER_LR_LAT_PRODUCT"])
        lr_lon = float(metadata["CORNER_LR_LON_PRODUCT"])
        bbox = [ul_lon, lr_lat, lr_lon, ul_lat]

        # Geometry as polygon (UL, UR, LR, LL, back to UL)
        geometry = {
            "type": "Polygon",
            "coordinates": [[
                [float(metadata["CORNER_UL_LON_PRODUCT"]), float(metadata["CORNER_UL_LAT_PRODUCT"])],
                [float(metadata["CORNER_UR_LON_PRODUCT"]), float(metadata["CORNER_UR_LAT_PRODUCT"])],
                [float(metadata["CORNER_LR_LON_PRODUCT"]), float(metadata["CORNER_LR_LAT_PRODUCT"])],
                [float(metadata["CORNER_LL_LON_PRODUCT"]), float(metadata["CORNER_LL_LAT_PRODUCT"])],
                [float(metadata["CORNER_UL_LON_PRODUCT"]), float(metadata["CORNER_UL_LAT_PRODUCT"])]
            ]]
        }


        # Acquisition time
        dt_str = metadata["DATE_ACQUIRED"] + "T" + metadata["SCENE_CENTER_TIME"]
        dt = parser.isoparse(dt_str)

        # Create item
        item = pystac.Item(
            id=metadata["LANDSAT_PRODUCT_ID"],
            bbox=bbox,
            geometry=geometry,
            datetime=dt,
            properties={
                "platform": metadata["SPACECRAFT_ID"].lower().replace("_", "-"),
                "instruments": [i.lower() for i in metadata["SENSOR_ID"].split("_")],
                "eo:cloud_cover": float(np.mean(cloud_cover)),
                "tilewise:cloud_cover": [float(c) for c in cloud_cover],
                "METADATA_AVAILABLE": data["metadata_available"],
                "CLOUD_COVER_AVAILABLE": data["cloud_cover_available"],
                "bands": data["bands"],
                "sat:off_nadir": 0.0,
                "sat:orbit_state": "descending",
                "gsd": 30
            }
        )
    elif data['platform'] == "GoogleEarthEngine" or data['platform'] == "wdcd":
        # Create a generic item for platforms without specific metadata
        item = pystac.Item(
            id=tile_id,
            bbox=[-180, -90, 180, 90],
            geometry={
                "type": "Polygon",
                "coordinates": [[
                    [-180, -90], [180, -90], 
                    [180, 90], [-180, 90], 
                    [-180, -90]
                ]]
            },
            datetime=datetime.now(),
            properties={
                "METADATA_AVAILABLE": data["metadata_available"],
                "CLOUD_COVER_AVAILABLE": data["cloud_cover_available"],
                "eo:cloud_cover": float(np.mean(cloud_cover)),
                "tilewise:cloud_cover": [float(c) for c in cloud_cover],
                "gsd":8
            }
        )
    elif data["platform"] == 'sentinel-2':
        
        tile = metadata['n1:Level-1C_User_Product']
        general_info = tile['n1:General_Info']['Product_Info']

        tile_id = general_info['PRODUCT_TYPE']
        sensing_time = general_info['GENERATION_TIME']
        
        geometric_info = tile['n1:Geometric_Info']

        # Convert sensing time to datetime
        dt = datetime.fromisoformat(sensing_time.replace("Z", "+00:00"))

        # Hardcode or extract values as needed
        platform = "sentinel-2a"
        instrument = ["msi"]
        
        coord_list = list(map(float, geometric_info['Product_Footprint']['Product_Footprint']['Global_Footprint']['EXT_POS_LIST'].split()))

        # Separate into lat/lon pairs and convert to list of [lon, lat] coordinates
        polygon_coords = []
        lats = []
        lons = []
        for i in range(0, len(coord_list), 2):
            lat = coord_list[i]
            lon = coord_list[i+1]
            polygon_coords.append([lon, lat])  # GeoJSON uses [lon, lat] order
            lats.append(lat)
            lons.append(lon)

        # Calculate bbox [min_lon, min_lat, max_lon, max_lat]
        bbox = [min(lons), min(lats), max(lons), max(lats)]

        # Create GeoJSON polygon (first and last point must be identical)
        geometry = {
            "type": "Polygon",
            "coordinates": [polygon_coords]  # Note the extra list wrapping for GeoJSON
        }
        
        # Create item
        item = pystac.Item(
            id=tile_id,
            bbox=bbox,
            geometry=geometry,
            datetime=dt,
            properties={
                "platform": platform,
                "instruments": instrument,
                "eo:cloud_cover": float(np.mean(cloud_cover)),
                "tilewise:cloud_cover": [float(c) for c in cloud_cover],
                "bands": data["bands"],
                "METADATA_AVAILABLE": True,
                "CLOUD_COVER_AVAILABLE": True,
                "sat:off_nadir": 0.0,
                "sat:orbit_state": "descending",
                "gsd": 10
            }
        )

    # Enable extensions
    EOExtension.add_to(item)
    SatExtension.add_to(item)

    # Add Zarr asset
    zarr_href = zarr_path  # Adjust as needed
    item.add_asset(
        "data_zarr",
        pystac.Asset(   
            href=zarr_href,
            media_type="application/vnd+zarr",
            roles=["data"],
            title=f"{data['platform']} Zarr Dataset",
            extra_fields={
                "xarray:open_kwargs": {"consolidated": True}
            }
        )
    )

    return item

# %%
def generate_stac(mtl_filename, variable_name, cloud_percentages, data):
    # Ensure the metadata file exists
    if(data['metadata_available']):
        metadata = parse_mtl(mtl_filename,data)
    else:
        metadata = ''
        

    # for i, cloud_cover in enumerate(cloud_percentages):
    minio_zarr_path = f"raw/{variable_name}.zarr"
    
    item = make_stac_item(metadata, minio_zarr_path, variable_name, cloud_percentages, data)
    item.save_object(dest_href=f"{variable_name}.json")
    
    # print(item.id)
    minio_stac_path = f"stac/{variable_name}.json"
    # print(f"Uploading STAC to MinIO: {minio_stac_path}")
    upload_to_minio(minio_client, bucket_name, f"{variable_name}.json", minio_stac_path)
    os.remove(f"{variable_name}.json")
    
    print(f"Generated and uploaded STAC items for variable '{variable_name}' with cloud cover percentages to MinIO bucket '{bucket_name}'.")

# %%
# Upload regular files and convert to zarr
for file_path in scenes_dir.glob("*"):
    
    # Read whole image
    if data['band_layout'] == 'stacked':
        for sub_file_path in file_path.glob("*"):    
            if sub_file_path.suffix == ".tif" or sub_file_path.suffix == ".TIF" or sub_file_path.suffix == ".tiff":

                scene = tifffile.imread(sub_file_path)
                
                variable_name = sub_file_path.stem
    
    # Stack disjoint bands   
    elif data['band_layout'] == 'disjoint':
        bands = ['B02','B03','B04','B08']
        stack = []
        for band in bands:
            for sub_file_path in file_path.glob(f"*{band}*"):
                
                img = Image.open(sub_file_path)
                stack.append(np.array(img))
                
        scene = np.stack(stack, axis=-1)
    
    variable_name = file_path.stem
    
    print(f"Variable name: {variable_name}")
            
    mask_path = masks_dir / variable_name
    
    for masks in mask_path.glob("*"):
        if masks.suffix == ".tif" or masks.suffix == ".TIF" or sub_file_path.suffix == ".tiff":
            mask = np.array(Image.open(masks))
            if data['platform'] == 'landsat-8':
                mask = mask.astype(np.uint8) * 255
            
    gt_tiles = tile_image(mask)
    
    padded_tiles = [pad_to_shape(tile) for tile in gt_tiles]
    padded_tiles_array = np.stack(padded_tiles)  # Shape: (N, 384, 384)
    percent_white = white_percentage_batch(padded_tiles_array)
    
    upload_zarr(scene, variable_name, bucket_name)
    
    metadata_path = metadata_dir / variable_name
    
    if data['metadata_available']:
        for metadata in metadata_path.glob("*"):
            generate_stac(metadata, variable_name, percent_white, data)
    else:
        generate_stac("", variable_name, percent_white, data)
        
    #delete the filepath we just worked on
    shutil.rmtree(file_path)
# Out:
# /home/ihsan/anaconda3/envs/ComputerVision/lib/python3.8/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (120560400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Variable name: S2A_MSIL1C_20191023T040821_N0208_R047_T47TQF_20191023T074550
# Uploaded tiles for variable 'S2A_MSIL1C_20191023T040821_N0208_R047_T47TQF_20191023T074550' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191023T040821_N0208_R047_T47TQF_20191023T074550' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191215T042151_N0208_R090_T46RGV_20191215T065406
# Uploaded tiles for variable 'S2A_MSIL1C_20191215T042151_N0208_R090_T46RGV_20191215T065406' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191215T042151_N0208_R090_T46RGV_20191215T065406' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20200325T034531_N0209_R104_T47RQL_20200325T065315
# Uploaded tiles for variable 'S2A_MSIL1C_20200325T034531_N0209_R104_T47RQL_20200325T065315' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20200325T034531_N0209_R104_T47RQL_20200325T065315' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190328T033701_N0207_R061_T49TCF_20190328T071457
# Uploaded tiles for variable 'S2A_MSIL1C_20190328T033701_N0207_R061_T49TCF_20190328T071457' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190328T033701_N0207_R061_T49TCF_20190328T071457' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190714T043711_N0208_R033_T46TFN_20190714T073938
# Uploaded tiles for variable 'S2A_MSIL1C_20190714T043711_N0208_R033_T46TFN_20190714T073938' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190714T043711_N0208_R033_T46TFN_20190714T073938' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190819T031541_N0208_R118_T49SFU_20190819T065332
# Uploaded tiles for variable 'S2A_MSIL1C_20190819T031541_N0208_R118_T49SFU_20190819T065332' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190819T031541_N0208_R118_T49SFU_20190819T065332' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180824T031541_N0206_R118_T50TKL_20180824T061636
# Uploaded tiles for variable 'S2A_MSIL1C_20180824T031541_N0206_R118_T50TKL_20180824T061636' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180824T031541_N0206_R118_T50TKL_20180824T061636' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191105T023901_N0208_R089_T51STR_20191105T054744
# Uploaded tiles for variable 'S2A_MSIL1C_20191105T023901_N0208_R089_T51STR_20191105T054744' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191105T023901_N0208_R089_T51STR_20191105T054744' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20200416T042701_N0209_R133_T46SFE_20200416T074050
# Uploaded tiles for variable 'S2A_MSIL1C_20200416T042701_N0209_R133_T46SFE_20200416T074050' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20200416T042701_N0209_R133_T46SFE_20200416T074050' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20210102T054231_N0209_R005_T43SFB_20210102T065941
# Uploaded tiles for variable 'S2A_MSIL1C_20210102T054231_N0209_R005_T43SFB_20210102T065941' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20210102T054231_N0209_R005_T43SFB_20210102T065941' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20200222T030731_N0209_R075_T49QEE_20200222T060244
# Uploaded tiles for variable 'S2A_MSIL1C_20200222T030731_N0209_R075_T49QEE_20200222T060244' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20200222T030731_N0209_R075_T49QEE_20200222T060244' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180429T032541_N0206_R018_T49SCV_20180429T062304
# Uploaded tiles for variable 'S2A_MSIL1C_20180429T032541_N0206_R018_T49SCV_20180429T062304' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180429T032541_N0206_R018_T49SCV_20180429T062304' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180816T053641_N0206_R005_T44TKK_20180816T093424
# Uploaded tiles for variable 'S2A_MSIL1C_20180816T053641_N0206_R005_T44TKK_20180816T093424' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180816T053641_N0206_R005_T44TKK_20180816T093424' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190815T051651_N0208_R062_T44TPN_20190815T090034
# Uploaded tiles for variable 'S2A_MSIL1C_20190815T051651_N0208_R062_T44TPN_20190815T090034' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190815T051651_N0208_R062_T44TPN_20190815T090034' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180729T025551_N0206_R032_T49RGL_20180729T055945
# Uploaded tiles for variable 'S2A_MSIL1C_20180729T025551_N0206_R032_T49RGL_20180729T055945' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180729T025551_N0206_R032_T49RGL_20180729T055945' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190928T031541_N0208_R118_T49RBJ_20190928T061248
# Uploaded tiles for variable 'S2A_MSIL1C_20190928T031541_N0208_R118_T49RBJ_20190928T061248' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190928T031541_N0208_R118_T49RBJ_20190928T061248' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20200410T022551_N0209_R046_T51TXG_20200410T042047
# Uploaded tiles for variable 'S2A_MSIL1C_20200410T022551_N0209_R046_T51TXG_20200410T042047' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20200410T022551_N0209_R046_T51TXG_20200410T042047' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191002T025551_N0208_R032_T50TQQ_20191002T054113
# Uploaded tiles for variable 'S2A_MSIL1C_20191002T025551_N0208_R032_T50TQQ_20191002T054113' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191002T025551_N0208_R032_T50TQQ_20191002T054113' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191118T025011_N0208_R132_T50RMN_20191118T071843
# Uploaded tiles for variable 'S2A_MSIL1C_20191118T025011_N0208_R132_T50RMN_20191118T071843' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191118T025011_N0208_R132_T50RMN_20191118T071843' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180930T030541_N0206_R075_T49QDD_20180930T060706
# Uploaded tiles for variable 'S2A_MSIL1C_20180930T030541_N0206_R075_T49QDD_20180930T060706' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180930T030541_N0206_R075_T49QDD_20180930T060706' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190602T021611_N0207_R003_T52TES_20190602T042019
# Uploaded tiles for variable 'S2A_MSIL1C_20190602T021611_N0207_R003_T52TES_20190602T042019' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190602T021611_N0207_R003_T52TES_20190602T042019' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191219T040151_N0208_R004_T47SQU_20191219T055033
# Uploaded tiles for variable 'S2A_MSIL1C_20191219T040151_N0208_R004_T47SQU_20191219T055033' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191219T040151_N0208_R004_T47SQU_20191219T055033' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180722T030541_N0206_R075_T49RFP_20180722T060550
# Uploaded tiles for variable 'S2A_MSIL1C_20180722T030541_N0206_R075_T49RFP_20180722T060550' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180722T030541_N0206_R075_T49RFP_20180722T060550' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190916T023551_N0208_R089_T50RQS_20190916T042547
# Uploaded tiles for variable 'S2A_MSIL1C_20190916T023551_N0208_R089_T50RQS_20190916T042547' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190916T023551_N0208_R089_T50RQS_20190916T042547' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190812T032541_N0208_R018_T48RXU_20190812T070322
# Uploaded tiles for variable 'S2A_MSIL1C_20190812T032541_N0208_R018_T48RXU_20190812T070322' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190812T032541_N0208_R018_T48RXU_20190812T070322' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20210207T023851_N0209_R089_T52UCU_20210207T040210
# Uploaded tiles for variable 'S2A_MSIL1C_20210207T023851_N0209_R089_T52UCU_20210207T040210' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20210207T023851_N0209_R089_T52UCU_20210207T040210' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20200317T024541_N0209_R132_T51TWM_20200317T053350
# Uploaded tiles for variable 'S2A_MSIL1C_20200317T024541_N0209_R132_T51TWM_20200317T053350' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20200317T024541_N0209_R132_T51TWM_20200317T053350' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20190630T045701_N0207_R119_T45SWC_20190630T080543
# Uploaded tiles for variable 'S2A_MSIL1C_20190630T045701_N0207_R119_T45SWC_20190630T080543' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20190630T045701_N0207_R119_T45SWC_20190630T080543' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180930T044701_N0206_R076_T45SXR_20180930T074413
# Uploaded tiles for variable 'S2A_MSIL1C_20180930T044701_N0206_R076_T45SXR_20180930T074413' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180930T044701_N0206_R076_T45SXR_20180930T074413' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20191001T050701_N0208_R019_T45TXN_20191002T142939
# Uploaded tiles for variable 'S2A_MSIL1C_20191001T050701_N0208_R019_T45TXN_20191002T142939' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20191001T050701_N0208_R019_T45TXN_20191002T142939' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20180827T032541_N0206_R018_T48RYV_20180827T062627
# Uploaded tiles for variable 'S2A_MSIL1C_20180827T032541_N0206_R018_T48RYV_20180827T062627' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20180827T032541_N0206_R018_T48RYV_20180827T062627' with cloud cover percentages to MinIO bucket 'fusion-lake'.
# Variable name: S2A_MSIL1C_20210126T052111_N0209_R062_T44SNE_20210126T063836
# Uploaded tiles for variable 'S2A_MSIL1C_20210126T052111_N0209_R062_T44SNE_20210126T063836' to MinIO bucket 'fusion-lake'.
# Generated and uploaded STAC items for variable 'S2A_MSIL1C_20210126T052111_N0209_R062_T44SNE_20210126T063836' with cloud cover percentages to MinIO bucket 'fusion-lake'.

# %%
masks_dir_temp = Path('Masks')
minio_mask_path = 's3://'

# %%
# Upload corresponding masks to MinIO
for mask_path in masks_dir_temp.glob('*'):
    variable_name = mask_path.stem
    
    for mask in mask_path.glob('*'):
        mask_image = np.array(Image.open(mask))
        mask_image = mask_image.astype(np.uint8)
        if mask_image.max() > 1:
            mask_image[mask_image < 255] = 0
            mask_image[mask_image == 255] = 1
        
        upload_zarr(mask_image, variable_name, 'fusion-lake')
        
    shutil.rmtree(mask_path)
# Out:
# Uploaded tiles for variable 'WDCD_09' to MinIO bucket 'fusion-lake'.
# /home/ihsan/anaconda3/envs/ComputerVision/lib/python3.8/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (120560400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Uploaded tiles for variable 'S2A_MSIL1C_20191023T040821_N0208_R047_T47TQF_20191023T074550' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_064012_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191215T042151_N0208_R090_T46RGV_20191215T065406' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_063013_20160920_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_02' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20200325T034531_N0209_R104_T47RQL_20200325T065315' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190328T033701_N0207_R061_T49TCF_20190328T071457' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190714T043711_N0208_R033_T46TFN_20190714T073938' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190819T031541_N0208_R118_T49SFU_20190819T065332' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_034037_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180824T031541_N0206_R118_T50TKL_20180824T061636' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191105T023901_N0208_R089_T51STR_20191105T054744' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_034033_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_063016_20160920_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20200416T042701_N0209_R133_T46SFE_20200416T074050' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_11' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_10' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_22' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_035034_20160120_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20210102T054231_N0209_R005_T43SFB_20210102T065941' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20200222T030731_N0209_R075_T49QEE_20200222T060244' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_029044_20160720_20170222_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_07' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_035035_20160120_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_24' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_039034_20160320_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_17' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_20' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_050024_20160520_20170324_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_045026_20160720_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_002053_20160520_20170324_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180429T032541_N0206_R018_T49SCV_20180429T062304' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180816T053641_N0206_R005_T44TKK_20180816T093424' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_011247_20160620_20170323_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_15' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_14' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_04' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_029032_20160720_20170222_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_032030_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_002054_20160520_20170324_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190815T051651_N0208_R062_T44TPN_20190815T090034' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180729T025551_N0206_R032_T49RGL_20180729T055945' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190928T031541_N0208_R118_T49RBJ_20190928T061248' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20200410T022551_N0209_R046_T51TXG_20200410T042047' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_066014_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_01' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_064015_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_034029_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_003052_20160120_20170405_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_03' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191002T025551_N0208_R032_T50TQQ_20191002T054113' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_13' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_044010_20160220_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_19' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191118T025011_N0208_R132_T50RMN_20191118T071843' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_011002_20160620_20170323_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_034034_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_018008_20160520_20170324_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_066017_20160520_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_032035_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180930T030541_N0206_R075_T49QDD_20180930T060706' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_064017_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_23' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190602T021611_N0207_R003_T52TES_20190602T042019' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_063012_20160920_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191219T040151_N0208_R004_T47SQU_20191219T055033' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_059014_20160620_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_12' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180722T030541_N0206_R075_T49RFP_20180722T060550' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_18' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_16' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_029040_20160720_20170222_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_08' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190916T023551_N0208_R089_T50RQS_20190916T042547' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_029041_20160720_20170222_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_039035_20160320_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190812T032541_N0208_R018_T48RXU_20190812T070322' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20210207T023851_N0209_R089_T52UCU_20210207T040210' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20200317T024541_N0209_R132_T51TWM_20200317T053350' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_035029_20160120_20170224_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20190630T045701_N0207_R119_T45SWC_20190630T080543' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_25' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_032037_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180930T044701_N0206_R076_T45SXR_20180930T074413' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_064014_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_032029_20160420_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_21' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_061017_20160720_20170223_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20191001T050701_N0208_R019_T45TXN_20191002T142939' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20180827T032541_N0206_R018_T48RYV_20180827T062627' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'LC08_L1TP_047023_20160920_20170221_01_T1' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_06' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'WDCD_05' to MinIO bucket 'fusion-lake'.
# Uploaded tiles for variable 'S2A_MSIL1C_20210126T052111_N0209_R062_T44SNE_20210126T063836' to MinIO bucket 'fusion-lake'.
